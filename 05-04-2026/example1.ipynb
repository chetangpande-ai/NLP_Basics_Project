# %%
documents = [
    "AI is powerful",
    "AI is easy",
    "AI is everywhere",
    "i am learning AI"
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

# %%
feature_names = vectorizer.get_feature_names_out()
print(feature_names)

print(tfidf_matrix.toarray())
# Out:
# ['ai' 'am' 'easy' 'everywhere' 'is' 'learning' 'powerful']
# [[0.40264194 0.         0.         0.         0.49248889 0.
#   0.77157901]
#  [0.40264194 0.         0.77157901 0.         0.49248889 0.
#   0.        ]
#  [0.40264194 0.         0.         0.77157901 0.49248889 0.
#   0.        ]
#  [0.34618161 0.66338461 0.         0.         0.         0.66338461
#   0.        ]]
