# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Ishan
# [nltk_data]     Pande\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
text = "Experienced QA engineer skilled in automation, API testing, and NLP."
tokens = word_tokenize(text)

print(tokens)
# Out:
# ['Experienced', 'QA', 'engineer', 'skilled', 'in', 'automation', ',', 'API', 'testing', ',', 'and', 'NLP', '.']
